# %%
# Mini Project : Number Guessing Game

import random

number = random.randint(1, 100)

print("====== Number Guessing Game ======")
print("Guess a number between 1 and 100")

attempts = 0

#loop
while True:

    guess = int(input("Enter your guessed number: "))
    attempts += 1

    # Conditional statements
    if guess < number:
        print("Too low! Try a bigger number.")

    elif guess > number:
        print("Too high! Try a smaller number.")

    else:
        print(" Congratulations!")
        print("You guessed the correct number:", number)
        print("Total attempts:", attempts)
        break

print("Thanks for playing!")
# Out:
# ====== Number Guessing Game ======
# Guess a number between 1 and 100
# Enter your guessed number:  40
# Too high! Try a smaller number.
# Enter your guessed number:  35
# Too high! Try a smaller number.
# Enter your guessed number:  23
# Too low! Try a bigger number.
# Enter your guessed number:  30
# Too low! Try a bigger number.
# Enter your guessed number:  31
# Too low! Try a bigger number.
# Enter your guessed number:  32
# Too low! Try a bigger number.
# Enter your guessed number:  33
#  Congratulations!
# You guessed the correct number: 33
# Total attempts: 7
# Thanks for playing!
